# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder
import keras
from tensorflow.keras.regularizers import l2
from keras import layers

# %%
data = pd.read_csv('C:/resources/6weeks/DSA_features.csv')
data = data.drop('people', axis=1)
data
# Out:
#       T_xacc_mean  T_xacc_max  T_xacc_min  T_xacc_var  T_xacc_std  \
# 0        7.975714      8.1605      7.6823    0.014395    0.119981
# 1        7.978250      8.1763      7.8472    0.007551    0.086896
# 2        7.970894      8.0860      7.8470    0.003092    0.055603
# 3        7.938412      8.1083      7.6901    0.003763    0.061343
# 4        7.908930      8.1305      7.8322    0.001741    0.041731
# 5        7.965544      8.1304      7.8691    0.004233    0.065059
# 6        7.923159      8.0482      7.8543    0.001490    0.038600
# 7        7.941025      8.0559      7.8468    0.003056    0.055283
# 8        7.882650      8.0483      7.6304    0.009832    0.099157
# 9        7.902089      8.0484      7.8318    0.002280    0.047751
# 10       7.890129      7.9959      7.8318    0.001223    0.034975
# 11       7.889739      8.0702      7.8018    0.002366    0.048644
# 12       7.877556      8.0109      7.7571    0.003556    0.059629
# ...

# %%
def split_sequences(sequences, n_steps, n_features):
    X, y = list(), list()
    for i in range(len(sequences)):
        # 시퀀스의 끝점 계산
        end_ix = i + n_steps
        # 데이터 범위를 넘어서면 중단
        if end_ix > len(sequences):
            break
        # 입력 시퀀스는 n_steps 동안의 데이터 (마지막 레이블 제외)
        seq_x = sequences[i:end_ix, :n_features]
        # 출력은 end_ix 시점에서 레이블만 가져옴
        seq_y = sequences[end_ix-1, n_features:]  # 특정 시점에서 레이블만 가져오기
        X.append(seq_x)
        y.append(seq_y)
    
    return np.array(X), np.array(y)

# %%
# 레이블과 특성 나누기
X = data.drop('activity', axis=1).values  # activity 컬럼을 제외한 모든 특성
y = data['activity'].values  # activity 레이블

# %%
# 시퀀스와 레이블 결합
combined_data = np.c_[X, y]  # 특성과 레이블 결합

# %%
# 시퀀스 생성
n_steps = 5  # 시퀀스 길이
n_features = X.shape[1]  # 특성 수
X, y = split_sequences(combined_data, n_steps, n_features)

# %%
# 데이터 증강 함수
def augment_data(X, y, augmentation_factor=2):
    X_augmented = []
    y_augmented = []
    
    for i in range(len(X)):
        # 원본 데이터 추가
        X_augmented.append(X[i])
        y_augmented.append(y[i])
        
        # 노이즈 추가
        noise = np.random.normal(0, 0.1, X[i].shape)
        X_augmented.append(X[i] + noise)
        y_augmented.append(y[i])
        
        # 시퀀스 반전
        X_augmented.append(np.flip(X[i], axis=0))
        y_augmented.append(y[i])
    
    # 결과를 numpy 배열로 변환
    return np.array(X_augmented), np.array(y_augmented)

# %%
# 데이터 증강 적용
X, y = augment_data(X, y)

# %%
X = X.astype(np.float32)  # X를 float32로 변환

# %%
# 레이블 정수 인코딩
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)
# Out:
# C:\anaconda\lib\site-packages\sklearn\preprocessing\label.py:111: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
# 원-핫 인코딩
n_classes = len(label_encoder.classes_)
y_categorical = to_categorical(y_encoded, num_classes=n_classes)

# %%
print("X shape:", X.shape)
print("y shape:", y_categorical.shape)
print("Number of classes:", n_classes)
# Out:
# X shape: (9116, 5, 270)
# y shape: (9116, 19)
# Number of classes: 19

# %%
def transformer_encoder(inputs, head_size, num_heads, ff_dim, dropout=0):
    x = layers.MultiHeadAttention(
        key_dim=head_size, num_heads=num_heads, dropout=dropout
    )(inputs, inputs)
    x = layers.Dropout(dropout)(x)
    x = layers.LayerNormalization(epsilon=1e-6)(x)
    res = x + inputs

    # Feed Forward Part
    x = layers.Conv1D(filters=ff_dim, kernel_size=1, activation="relu", 
                      kernel_regularizer=l2(0.01))(res)  # L2 정규화 추가
    x = layers.Dropout(dropout)(x)
    x = layers.Conv1D(filters=inputs.shape[-1], kernel_size=1, 
                      kernel_regularizer=l2(0.01))(x)  # L2 정규화 추가
    x = layers.LayerNormalization(epsilon=1e-6)(x)
    return x + res

# %%
def build_model(
    input_shape,
    head_size,
    num_heads,
    ff_dim,
    num_transformer_blocks,
    mlp_units,
    dropout=0,
    mlp_dropout=0,
):
    inputs = keras.Input(shape=input_shape)
    x = inputs
    for _ in range(num_transformer_blocks):
        x = transformer_encoder(x, head_size, num_heads, ff_dim, dropout)

    x = layers.GlobalAveragePooling1D(data_format="channels_last")(x)
    for dim in mlp_units:
        x = layers.Dense(dim, activation="relu")(x)
        x = layers.Dropout(mlp_dropout)(x)
    outputs = layers.Dense(n_classes, activation="softmax")(x)
    return keras.Model(inputs, outputs)

# %%
# 모델 구축
input_shape = X.shape[1:]  # 입력 형태 설정

model = build_model(
    input_shape,
    head_size=256,
    num_heads=4,
    ff_dim=4,
    num_transformer_blocks=4,
    mlp_units=[128],
    mlp_dropout=0.4,
    dropout=0.25,
)

# %%
model.compile(
    loss="categorical_crossentropy",
    optimizer=Adam(learning_rate=1e-4),  # Adam 옵티마이저 사용
    metrics=["categorical_accuracy"],
)
# 모델 요약
model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_3 (InputLayer)            [(None, 5, 270)]     0
# __________________________________________________________________________________________________
# multi_head_attention_8 (MultiHe (None, 5, 270)       1109262     input_3[0][0]
#                                                                  input_3[0][0]
# __________________________________________________________________________________________________
# dropout_18 (Dropout)            (None, 5, 270)       0           multi_head_attention_8[0][0]
# __________________________________________________________________________________________________
# layer_normalization_16 (LayerNo (None, 5, 270)       540         dropout_18[0][0]
# ...

# %%
# 조기 종료 콜백 설정
callbacks = [
    keras.callbacks.EarlyStopping(
        monitor='val_loss',  # 모니터링할 메트릭 설정
        patience=10,         # 개선되지 않을 때 기다리는 에포크 수
        restore_best_weights=True  # 가장 좋은 성능의 가중치 복원
    )
]

# %%
# 모델 학습
callbacks = [keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True)]
history = model.fit(
    X,
    y_categorical,
    validation_split=0.2,
    epochs=50,
    batch_size=64,
    callbacks=callbacks,
)
# Out:
# Epoch 1/50
# 114/114 [==============================] - 9s 67ms/step - loss: 2.7375 - categorical_accuracy: 0.6144 - val_loss: 20.4021 - val_categorical_accuracy: 0.2050
# Epoch 2/50
# 114/114 [==============================] - 7s 65ms/step - loss: 1.0486 - categorical_accuracy: 0.8594 - val_loss: 24.0741 - val_categorical_accuracy: 0.2023
# Epoch 3/50
# 114/114 [==============================] - 8s 66ms/step - loss: 0.8478 - categorical_accuracy: 0.9307 - val_loss: 24.4762 - val_categorical_accuracy: 0.2061
# Epoch 4/50
# 114/114 [==============================] - 8s 66ms/step - loss: 0.7610 - categorical_accuracy: 0.9494 - val_loss: 23.3450 - val_categorical_accuracy: 0.1678
# Epoch 5/50
# 114/114 [==============================] - 7s 66ms/step - loss: 0.6975 - categorical_accuracy: 0.9642 - val_loss: 25.3407 - val_categorical_accuracy: 0.2072
# Epoch 6/50
# ...

# %% [markdown]
# <h1>오버피팅이 일어나서 38까지 나왔었는데 학습률 줄이고 데이터 증가, 조기 종료, 가중치 규제, 드롭다운 수정 까지 해봤는데도 안되요</h1>
