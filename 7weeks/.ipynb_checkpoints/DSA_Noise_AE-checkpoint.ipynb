# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.optimizers import Adam

# %%
# 1. 데이터 로드 및 전처리
df = pd.read_csv('C:/resources/DeepLearning/DSA_features.csv')
df
# Out:
#       T_xacc_mean  T_xacc_max  T_xacc_min  T_xacc_var  T_xacc_std  \
# 0        7.975714      8.1605      7.6823    0.014395    0.119981
# 1        7.978250      8.1763      7.8472    0.007551    0.086896
# 2        7.970894      8.0860      7.8470    0.003092    0.055603
# 3        7.938412      8.1083      7.6901    0.003763    0.061343
# 4        7.908930      8.1305      7.8322    0.001741    0.041731
# ...           ...         ...         ...         ...         ...
# 9115     8.280854     34.1980     -2.9038   28.080803    5.299132
# 9116     9.591118     51.6970     -3.4129   35.722025    5.976791
# 9117     9.599113     27.9300     -1.0765   48.850886    6.989341
# 9118     9.692482     72.7820     -2.6734   59.378336    7.705734
# 9119     9.380641     45.0090     -3.5938   40.459334    6.360765
#
#       T_xacc_skew  T_yacc_mean  T_yacc_max  T_yacc_min  T_yacc_var  ...  \
# 0       -0.023319     1.083150      1.1832     0.99744    0.002208  ...
# 1        0.552416     1.140865      1.2129     1.05810    0.000784  ...
# 2        0.100538     1.140962      1.2128     1.07960    0.000508  ...
# 3       -0.231914     1.165260      1.3170     1.07870    0.002173  ...
# 4        2.042285     1.187504      1.2574     1.09450    0.000662  ...
# ...           ...          ...         ...         ...         ...  ...
# 9115     1.350075    -1.491537     11.2240   -11.65100   14.670334  ...
# 9116     2.981144     0.086304      6.9951   -11.76400    5.329897  ...
# 9117     0.449237    -0.728367      3.7801    -8.36910    5.683022  ...
# 9118     4.491114    -0.582724      6.1216    -8.85710    4.162963  ...
# 9119     1.688626    -0.266325      5.8603    -6.91970    4.017098  ...
#
#       LL_ymag_std  LL_ymag_skew  LL_zmag_mean  LL_zmag_max  LL_zmag_min  \
# 0        0.000792      0.177075     -0.057119    -0.054963    -0.059241
# 1        0.000860     -0.286918     -0.057268    -0.054945    -0.059589
# 2        0.000762     -0.134430     -0.057068    -0.054711    -0.059065
# 3        0.000735      0.021485     -0.056422    -0.053670    -0.058310
# 4        0.000824     -0.148229     -0.055801    -0.053313    -0.057815
# ...           ...           ...           ...          ...          ...
# 9115     0.200829     -0.040701      0.297666     0.708480    -0.117430
# 9116     0.148745     -0.266377      0.224716     0.554670    -0.250950
# 9117     0.310748     -0.009505     -0.237786     0.088854    -0.477260
# 9118     0.156493      0.050624      0.533023     0.677800     0.055941
# 9119     0.229154     -0.342228      0.491919     0.707920     0.251280
#
#        LL_zmag_var  LL_zmag_std  LL_zmag_skew    activity  people
# 0     6.778722e-07     0.000823      0.036729     sitting      p1
# 1     7.032302e-07     0.000839      0.347471     sitting      p1
# 2     6.268222e-07     0.000792      0.045579     sitting      p1
# 3     8.011245e-07     0.000895      0.240690     sitting      p1
# 4     6.853423e-07     0.000828      0.258429     sitting      p1
# ...            ...          ...           ...         ...     ...
# 9115  4.135451e-02     0.203358     -0.310022  basketBall      p8
# 9116  3.355704e-02     0.183186     -0.736410  basketBall      p8
# 9117  2.026107e-02     0.142341      0.668438  basketBall      p8
# 9118  1.356379e-02     0.116464     -1.482489  basketBall      p8
# 9119  9.358254e-03     0.096738     -0.223302  basketBall      p8
#
# [9120 rows x 272 columns]

# %%
#데이터셋의 activity가 standing과 lying으로 시작하는 애들만 남도록
df = df[(df['activity'] == 'standing') | (df['activity'].str.startswith('lying'))]
df
# Out:
#       T_xacc_mean  T_xacc_max  T_xacc_min  T_xacc_var  T_xacc_std  \
# 480      8.416815      8.5783      8.3103    0.002356    0.048537
# 481      8.439497      8.6153      8.1908    0.005754    0.075855
# 482      8.442786      8.5184      8.3690    0.000786    0.028033
# 483      8.444243      8.5480      8.3692    0.001558    0.039470
# 484      8.347373      8.4138      8.2791    0.000774    0.027822
# ...           ...         ...         ...         ...         ...
# 1915     2.620502      2.6592      2.5891    0.000199    0.014113
# 1916     2.613423      2.6572      2.5815    0.000207    0.014387
# 1917     2.614750      2.6576      2.5654    0.000257    0.016018
# 1918     2.620167      2.6589      2.5781    0.000216    0.014691
# 1919     2.615565      2.6789      2.5734    0.000310    0.017610
#
#       T_xacc_skew  T_yacc_mean  T_yacc_max  T_yacc_min  T_yacc_var  ...  \
# 480      0.867785     0.571528     0.73677     0.35819    0.004036  ...
# 481      0.092156     0.499881     0.63267     0.32807    0.004515  ...
# 482      0.096127     0.429967     0.59482     0.32835    0.001260  ...
# 483      0.361301     0.414673     0.49073     0.33563    0.000867  ...
# 484      0.018596     0.441606     0.52153     0.37246    0.001067  ...
# ...           ...          ...         ...         ...         ...  ...
# 1915     0.148452    -9.392025    -9.34240    -9.42070    0.000242  ...
# 1916     0.368746    -9.398851    -9.36570    -9.43560    0.000156  ...
# 1917    -0.007991    -9.397350    -9.36280    -9.43130    0.000214  ...
# 1918    -0.114904    -9.397014    -9.36490    -9.45390    0.000257  ...
# 1919     0.608394    -9.398614    -9.36610    -9.42790    0.000167  ...
#
#       LL_ymag_std  LL_ymag_skew  LL_zmag_mean  LL_zmag_max  LL_zmag_min  \
# 480      0.001131      0.243260      0.644246      0.64700      0.64109
# 481      0.001678      0.391596      0.643432      0.64789      0.63942
# 482      0.001327      0.753549      0.643036      0.64646      0.64019
# 483      0.003490      0.178568      0.643370      0.64657      0.64004
# 484      0.000940     -0.237978      0.643874      0.64611      0.64063
# ...           ...           ...           ...          ...          ...
# 1915     0.009589      0.401254     -0.410987     -0.38221     -0.44605
# 1916     0.008588      0.147180     -0.411248     -0.36581     -0.43676
# 1917     0.005814      0.032341     -0.409787     -0.37926     -0.43431
# 1918     0.009510      0.409508     -0.409101     -0.36074     -0.44087
# 1919     0.009874      0.413339     -0.410440     -0.38588     -0.43841
#
#       LL_zmag_var  LL_zmag_std  LL_zmag_skew   activity  people
# 480      0.000002     0.001313     -0.184083   standing      p1
# 481      0.000003     0.001805      0.239917   standing      p1
# 482      0.000002     0.001447      0.178525   standing      p1
# 483      0.000003     0.001771      0.080492   standing      p1
# 484      0.000001     0.001219     -0.291443   standing      p1
# ...           ...          ...           ...        ...     ...
# 1915     0.000099     0.009967     -0.597598  lyingRigh      p8
# 1916     0.000087     0.009306      1.021454  lyingRigh      p8
# 1917     0.000073     0.008520      0.431012  lyingRigh      p8
# 1918     0.000113     0.010620      1.368666  lyingRigh      p8
# 1919     0.000072     0.008495      0.054973  lyingRigh      p8
#
# [1440 rows x 272 columns]

# %%
#곁측치 확인
df.isnull().values.any()
df = df.dropna()

# %%
df.loc[df['activity'] == 'standing', 'activity'] = 1
df.loc[df['activity'].str.startswith('lying', na=False), 'activity'] = 0
df
# Out:
#       T_xacc_mean  T_xacc_max  T_xacc_min  T_xacc_var  T_xacc_std  \
# 480      8.416815      8.5783      8.3103    0.002356    0.048537
# 481      8.439497      8.6153      8.1908    0.005754    0.075855
# 482      8.442786      8.5184      8.3690    0.000786    0.028033
# 483      8.444243      8.5480      8.3692    0.001558    0.039470
# 484      8.347373      8.4138      8.2791    0.000774    0.027822
# ...           ...         ...         ...         ...         ...
# 1915     2.620502      2.6592      2.5891    0.000199    0.014113
# 1916     2.613423      2.6572      2.5815    0.000207    0.014387
# 1917     2.614750      2.6576      2.5654    0.000257    0.016018
# 1918     2.620167      2.6589      2.5781    0.000216    0.014691
# 1919     2.615565      2.6789      2.5734    0.000310    0.017610
#
#       T_xacc_skew  T_yacc_mean  T_yacc_max  T_yacc_min  T_yacc_var  ...  \
# 480      0.867785     0.571528     0.73677     0.35819    0.004036  ...
# 481      0.092156     0.499881     0.63267     0.32807    0.004515  ...
# 482      0.096127     0.429967     0.59482     0.32835    0.001260  ...
# 483      0.361301     0.414673     0.49073     0.33563    0.000867  ...
# 484      0.018596     0.441606     0.52153     0.37246    0.001067  ...
# ...           ...          ...         ...         ...         ...  ...
# 1915     0.148452    -9.392025    -9.34240    -9.42070    0.000242  ...
# 1916     0.368746    -9.398851    -9.36570    -9.43560    0.000156  ...
# 1917    -0.007991    -9.397350    -9.36280    -9.43130    0.000214  ...
# 1918    -0.114904    -9.397014    -9.36490    -9.45390    0.000257  ...
# 1919     0.608394    -9.398614    -9.36610    -9.42790    0.000167  ...
#
#       LL_ymag_std  LL_ymag_skew  LL_zmag_mean  LL_zmag_max  LL_zmag_min  \
# 480      0.001131      0.243260      0.644246      0.64700      0.64109
# 481      0.001678      0.391596      0.643432      0.64789      0.63942
# 482      0.001327      0.753549      0.643036      0.64646      0.64019
# 483      0.003490      0.178568      0.643370      0.64657      0.64004
# 484      0.000940     -0.237978      0.643874      0.64611      0.64063
# ...           ...           ...           ...          ...          ...
# 1915     0.009589      0.401254     -0.410987     -0.38221     -0.44605
# 1916     0.008588      0.147180     -0.411248     -0.36581     -0.43676
# 1917     0.005814      0.032341     -0.409787     -0.37926     -0.43431
# 1918     0.009510      0.409508     -0.409101     -0.36074     -0.44087
# 1919     0.009874      0.413339     -0.410440     -0.38588     -0.43841
#
#       LL_zmag_var  LL_zmag_std  LL_zmag_skew  activity  people
# 480      0.000002     0.001313     -0.184083         1      p1
# 481      0.000003     0.001805      0.239917         1      p1
# 482      0.000002     0.001447      0.178525         1      p1
# 483      0.000003     0.001771      0.080492         1      p1
# 484      0.000001     0.001219     -0.291443         1      p1
# ...           ...          ...           ...       ...     ...
# 1915     0.000099     0.009967     -0.597598         0      p8
# 1916     0.000087     0.009306      1.021454         0      p8
# 1917     0.000073     0.008520      0.431012         0      p8
# 1918     0.000113     0.010620      1.368666         0      p8
# 1919     0.000072     0.008495      0.054973         0      p8
#
# [1440 rows x 272 columns]

# %%
df['activity'].value_counts()
# Out:
# activity
# 0    960
# 1    480
# Name: count, dtype: int64

# %%
#frauds = df[df.activity == 1]
#normal = df[df.activity == 0]
#frauds.shape

# %%
#normal.shape

# %%
from sklearn.preprocessing import StandardScaler

data = df.drop(['people'], axis=1)

# 스케일러 생성
#scaler = StandardScaler()

# 전체 컬럼을 스케일링
#data = scaler.fit_transform(data)
#data

# %%
# 테스트 레이블을 남겨두는 이유는 나중에 정확도를 비교하기 위해서임
RANDOM_SEED = 42
X_train, X_test = train_test_split(data, test_size=0.2, random_state=RANDOM_SEED)
X_train = X_train[X_train.activity == 0]
X_train = X_train.drop(['activity'], axis=1)

y_test = X_test['activity']
X_test = X_test.drop(['activity'], axis=1)

X_train = X_train.values
X_test = X_test.values
X_train.shape
# Out:
# (763, 270)

# %%
# 오토인코더 모델

input_dim = X_train.shape[1]
encoding_dim = 14  # 인코딩 차원을 설정 (임의로 설정한 값, 조정 가능)

input_layer = Input(shape=(input_dim,))
encoded = Dense(encoding_dim, activation='relu')(input_layer)
encoded = Dense(int(encoding_dim / 2), activation='relu')(encoded)
decoded = Dense(int(encoding_dim / 2), activation='relu')(encoded)
decoded = Dense(input_dim, activation='sigmoid')(decoded)

autoencoder = Model(inputs=input_layer, outputs=decoded)
autoencoder.compile(optimizer=Adam(learning_rate=0.001), loss='mse')

# %%
# 3. 모델 학습
# 훈련데이터의 0.1 을 validation data로 사용
history = autoencoder.fit(X_train, X_train,
                          epochs=100, 
                          batch_size=256, 
                          shuffle=True, 
                          validation_split = 0.1)
# Out:
# Epoch 1/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step - loss: 5.7487 - val_loss: 5.7534
# Epoch 2/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 5.7275 - val_loss: 5.7444
# Epoch 3/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 5.7481 - val_loss: 5.7343
# Epoch 4/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 5.7492 - val_loss: 5.7218
# Epoch 5/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 5.7241 - val_loss: 5.7066
# Epoch 6/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 5.7180 - val_loss: 5.6877
# Epoch 7/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 5.7119 - val_loss: 5.6646
# Epoch 8/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 5.6254 - val_loss: 5.6373
# Epoch 9/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 5.6413 - val_loss: 5.6061
# Epoch 10/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 5.6295 - val_loss: 5.5712
# Epoch 11/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 5.5951 - val_loss: 5.5330
# Epoch 12/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 5.5431 - val_loss: 5.4915
# Epoch 13/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 5.4918 - val_loss: 5.4471
# Epoch 14/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 5.4672 - val_loss: 5.4013
# Epoch 15/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 5.4192 - val_loss: 5.3553
# Epoch 16/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 5.3361 - val_loss: 5.3105
# Epoch 17/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 5.3539 - val_loss: 5.2681
# Epoch 18/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 5.2464 - val_loss: 5.2292
# Epoch 19/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 5.2629 - val_loss: 5.1944
# Epoch 20/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 5.2383 - val_loss: 5.1643
# Epoch 21/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 5.1466 - val_loss: 5.1388
# Epoch 22/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 5.1445 - val_loss: 5.1175
# Epoch 23/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 5.1315 - val_loss: 5.1001
# Epoch 24/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 5.0672 - val_loss: 5.0861
# Epoch 25/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 5.0968 - val_loss: 5.0748
# Epoch 26/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 5.0797 - val_loss: 5.0659
# Epoch 27/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 5.0740 - val_loss: 5.0591
# Epoch 28/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 5.0227 - val_loss: 5.0535
# Epoch 29/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 5.0941 - val_loss: 5.0489
# Epoch 30/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 5.0833 - val_loss: 5.0449
# Epoch 31/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 5.0061 - val_loss: 5.0410
# Epoch 32/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 5.0662 - val_loss: 5.0370
# Epoch 33/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 5.0821 - val_loss: 5.0327
# Epoch 34/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 5.0623 - val_loss: 5.0279
# Epoch 35/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 5.0432 - val_loss: 5.0227
# Epoch 36/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 4.9907 - val_loss: 5.0177
# Epoch 37/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 5.0432 - val_loss: 5.0131
# Epoch 38/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 5.0526 - val_loss: 5.0090
# Epoch 39/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 5.0114 - val_loss: 5.0052
# Epoch 40/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 4.9974 - val_loss: 5.0014
# Epoch 41/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 5.0491 - val_loss: 4.9974
# Epoch 42/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 4.9762 - val_loss: 4.9931
# Epoch 43/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 4.9599 - val_loss: 4.9883
# Epoch 44/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 4.9393 - val_loss: 4.9828
# Epoch 45/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 4.9584 - val_loss: 4.9768
# Epoch 46/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 5.0188 - val_loss: 4.9706
# Epoch 47/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 4.9935 - val_loss: 4.9643
# Epoch 48/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 4.9577 - val_loss: 4.9582
# Epoch 49/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 4.9638 - val_loss: 4.9528
# Epoch 50/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 4.9842 - val_loss: 4.9479
# Epoch 51/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.9254 - val_loss: 4.9436
# Epoch 52/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 4.8983 - val_loss: 4.9394
# Epoch 53/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.9447 - val_loss: 4.9354
# Epoch 54/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 4.9124 - val_loss: 4.9315
# Epoch 55/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 4.9700 - val_loss: 4.9278
# Epoch 56/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.9088 - val_loss: 4.9243
# Epoch 57/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 4.9374 - val_loss: 4.9212
# Epoch 58/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 4.8993 - val_loss: 4.9186
# Epoch 59/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.8804 - val_loss: 4.9160
# Epoch 60/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 4.9641 - val_loss: 4.9128
# Epoch 61/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 4.9350 - val_loss: 4.9095
# Epoch 62/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 4.8811 - val_loss: 4.9066
# Epoch 63/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 4.8803 - val_loss: 4.9041
# Epoch 64/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 4.8974 - val_loss: 4.9016
# Epoch 65/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 4.8676 - val_loss: 4.8992
# Epoch 66/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 4.8988 - val_loss: 4.8975
# Epoch 67/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 4.9359 - val_loss: 4.8961
# Epoch 68/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 4.9003 - val_loss: 4.8945
# Epoch 69/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 4.8445 - val_loss: 4.8930
# Epoch 70/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 4.8922 - val_loss: 4.8918
# Epoch 71/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.9065 - val_loss: 4.8907
# Epoch 72/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 4.9207 - val_loss: 4.8899
# Epoch 73/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.9314 - val_loss: 4.8891
# Epoch 74/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 4.8654 - val_loss: 4.8885
# Epoch 75/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 4.9097 - val_loss: 4.8878
# Epoch 76/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 4.8749 - val_loss: 4.8872
# Epoch 77/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 4.8817 - val_loss: 4.8866
# Epoch 78/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 4.9288 - val_loss: 4.8860
# Epoch 79/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 4.8575 - val_loss: 4.8854
# Epoch 80/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 4.9184 - val_loss: 4.8849
# Epoch 81/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 4.9332 - val_loss: 4.8844
# Epoch 82/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 4.8759 - val_loss: 4.8839
# Epoch 83/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 4.9357 - val_loss: 4.8835
# Epoch 84/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 4.8742 - val_loss: 4.8831
# Epoch 85/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 4.9065 - val_loss: 4.8828
# Epoch 86/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 4.9072 - val_loss: 4.8825
# Epoch 87/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 4.8710 - val_loss: 4.8821
# Epoch 88/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 4.9302 - val_loss: 4.8818
# Epoch 89/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 4.8702 - val_loss: 4.8814
# Epoch 90/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 4.8986 - val_loss: 4.8812
# Epoch 91/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 4.8729 - val_loss: 4.8809
# Epoch 92/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 4.8809 - val_loss: 4.8806
# Epoch 93/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 4.9250 - val_loss: 4.8803
# Epoch 94/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 4.8516 - val_loss: 4.8800
# Epoch 95/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 4.9195 - val_loss: 4.8798
# Epoch 96/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 4.8361 - val_loss: 4.8795
# Epoch 97/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 4.8823 - val_loss: 4.8793
# Epoch 98/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.9022 - val_loss: 4.8791
# Epoch 99/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 4.9263 - val_loss: 4.8789
# Epoch 100/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 4.8591 - val_loss: 4.8787

# %%
# X_test 값을 넣어서 Reconstruction Error 값을 얻고,
# 실제 레이블인 y_test와 데이터프레임으로 구성
# Reconstruction Error + 실제 레이블의 형태가 됨

decoded_data  = autoencoder.predict(X_test)
reconstruction_error = np.mean(np.abs(X_test - decoded_data), axis=1)
# threshold 값을 조정하여 최선의 정확도를 얻음, 그래프로를 보고 결정

threshold = .83
predictions = (reconstruction_error > threshold).astype(int)
error_df = pd.DataFrame({'reconstruction_error': reconstruction_error,
                         'Predicted Label': predictions,
                         'true_class': y_test})
error_df.describe()
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
#        reconstruction_error  Predicted Label
# count            288.000000       288.000000
# mean               0.825766         0.482639
# std                0.053040         0.500568
# min                0.721228         0.000000
# 25%                0.786123         0.000000
# 50%                0.828453         0.000000
# 75%                0.856208         1.000000
# max                1.091268         1.000000

# %%
error_df.head()
# Out:
#       reconstruction_error  Predicted Label true_class
# 648               0.894668                1          1
# 1085              0.866296                1          0
# 1028              0.815447                0          0
# 545               0.828747                0          1
# 1108              0.859519                1          0

# %%
groups = error_df.groupby('true_class')
fig, ax = plt.subplots()

for name, group in groups:
    ax.plot(group.index, group.reconstruction_error, marker='o', ms=3.5, linestyle='',
            label= "Fraud" if name == 1 else "Normal")
ax.hlines(threshold, ax.get_xlim()[0], ax.get_xlim()[1], colors="r", zorder=100, label='Threshold')
ax.legend()
plt.title("Reconstruction error for different classes")
plt.ylabel("Reconstruction error")
plt.xlabel("Data point index")
plt.show();

# %%
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# true_class를 NumPy 배열로 변환
true_class = error_df.true_class.values

# y_pred를 NumPy 배열로 변환
y_pred = np.array([1 if e > threshold else 0 for e in error_df.reconstruction_error.values])

# 데이터 타입 확인
print("Data type of true_class:", type(true_class), true_class.dtype)
print("Data type of y_pred:", type(y_pred), y_pred.dtype)

# 정수형으로 변환
true_class = true_class.astype(int)
y_pred = y_pred.astype(int)

# 길이 확인
print("Length of true_class:", len(true_class))
print("Length of y_pred:", len(y_pred))

# 혼동 행렬 계산
conf_matrix = confusion_matrix(true_class, y_pred)

# 시각화
plt.figure(figsize=(8, 8))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap='Blues')
plt.title("Confusion Matrix")
plt.ylabel('True Class')
plt.xlabel('Predicted Class')
plt.show()

# 분류 리포트 출력
print(classification_report(true_class, y_pred))
# Out:
# Data type of true_class: <class 'numpy.ndarray'> object
# Data type of y_pred: <class 'numpy.ndarray'> int32
# Length of true_class: 288
# Length of y_pred: 288
#               precision    recall  f1-score   support
#
#            0       0.89      0.67      0.76       197
#            1       0.53      0.81      0.64        91
#
#     accuracy                           0.72       288
#    macro avg       0.71      0.74      0.70       288
# weighted avg       0.77      0.72      0.73       288
